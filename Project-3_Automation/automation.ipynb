# %%
import pandas as pd
One_piece = pd.read_html("https://en.wikipedia.org/wiki/One_Piece_(TV_series)")

# %%
len(One_piece)
# Out:
# 26

# %%
One_piece[2]
# Out:
#    Season                                       Season title Episodes  \
#    Season                                       Season title Episodes
# 0       1                                       East Blue[4]       61
# 1       2                       Entering into the Grand Line       16
# 2       3           Introducing Chopper at the Winter Island       14
# 3       4              Arrival & Fierce Fighting in Alabasta       39
# 4       5  Dreams!, The Zenny Pirate Crew Sortie!, Beyond...       13
# 5       6             Sky Island ~ Skypiea & The Golden Bell       52
# 6       7  Escape! The Marine Fortress & The Foxy Pirate ...       33
# 7       8                                        Water Seven       35
# 8       9                                        Enies Lobby       73
# 9      10                                      Thriller Bark       45
# 10     11                                Sabaody Archipelago       26
# ...
