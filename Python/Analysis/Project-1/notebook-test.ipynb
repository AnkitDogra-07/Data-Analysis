# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
pwd = os.getcwd()

# %%
dataset = pd.read_csv("data-IPL_Ball_by_Ball_2008_2022.csv")
dataset
# Out:
#              ID  innings  overs  ballnumber       batter          bowler  \
# 0       1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1       1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2       1312200        1      0           3   JC Buttler  Mohammed Shami
# 3       1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4       1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# ...         ...      ...    ...         ...          ...             ...
# 225949   335982        2     14           5      P Kumar        I Sharma
# 225950   335982        2     14           6     SB Joshi        I Sharma
# 225951   335982        2     14           7      P Kumar        I Sharma
# 225952   335982        2     15           1     SB Joshi       LR Shukla
# 225953   335982        2     15           2     SB Joshi       LR Shukla
#
#         non-striker extra_type  batsman_run  extras_run  total_run  \
# ...

# %%
dataset.columns
# Out:
# Index(['ID', 'innings', 'overs', 'ballnumber', 'batter', 'bowler',
#        'non-striker', 'extra_type', 'batsman_run', 'extras_run', 'total_run',
#        'non_boundary', 'isWicketDelivery', 'player_out', 'kind',
#        'fielders_involved', 'BattingTeam'],
#       dtype='object')

# %%
modified_df = dataset.copy()
modified_df
# Out:
#              ID  innings  overs  ballnumber       batter          bowler  \
# 0       1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1       1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2       1312200        1      0           3   JC Buttler  Mohammed Shami
# 3       1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4       1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# ...         ...      ...    ...         ...          ...             ...
# 225949   335982        2     14           5      P Kumar        I Sharma
# 225950   335982        2     14           6     SB Joshi        I Sharma
# 225951   335982        2     14           7      P Kumar        I Sharma
# 225952   335982        2     15           1     SB Joshi       LR Shukla
# 225953   335982        2     15           2     SB Joshi       LR Shukla
#
#         non-striker extra_type  batsman_run  extras_run  total_run  \
# ...

# %%
col_to_drop = list(modified_df.columns[13:16])

# %%
modified_df.drop(columns=col_to_drop, inplace = True)
modified_df.columns
# Out:
# Index(['ID', 'innings', 'overs', 'ballnumber', 'batter', 'bowler',
#        'non-striker', 'extra_type', 'batsman_run', 'extras_run', 'total_run',
#        'non_boundary', 'isWicketDelivery', 'BattingTeam'],
#       dtype='object')

# %%
columns_to_drop = ['ballnumber', 'extra_type']
modified_df
# Out:
#              ID  innings  overs  ballnumber       batter          bowler  \
# 0       1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1       1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2       1312200        1      0           3   JC Buttler  Mohammed Shami
# 3       1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4       1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# ...         ...      ...    ...         ...          ...             ...
# 225949   335982        2     14           5      P Kumar        I Sharma
# 225950   335982        2     14           6     SB Joshi        I Sharma
# 225951   335982        2     14           7      P Kumar        I Sharma
# 225952   335982        2     15           1     SB Joshi       LR Shukla
# 225953   335982        2     15           2     SB Joshi       LR Shukla
#
#         non-striker extra_type  batsman_run  extras_run  total_run  \
# ...

# %%
modified_df.drop(columns=columns_to_drop, inplace = True)
modified_df
# Out:
#              ID  innings  overs       batter          bowler  non-striker  \
# 0       1312200        1      0  YBK Jaiswal  Mohammed Shami   JC Buttler
# 1       1312200        1      0  YBK Jaiswal  Mohammed Shami   JC Buttler
# 2       1312200        1      0   JC Buttler  Mohammed Shami  YBK Jaiswal
# 3       1312200        1      0  YBK Jaiswal  Mohammed Shami   JC Buttler
# 4       1312200        1      0  YBK Jaiswal  Mohammed Shami   JC Buttler
# ...         ...      ...    ...          ...             ...          ...
# 225949   335982        2     14      P Kumar        I Sharma     SB Joshi
# 225950   335982        2     14     SB Joshi        I Sharma      P Kumar
# 225951   335982        2     14      P Kumar        I Sharma     SB Joshi
# 225952   335982        2     15     SB Joshi       LR Shukla      P Kumar
# 225953   335982        2     15     SB Joshi       LR Shukla      P Kumar
#
#         batsman_run  extras_run  total_run  non_boundary  isWicketDelivery  \
# ...

# %%
grp_data = modified_df.groupby(['bowler'])['isWicketDelivery'].agg('sum')
grp_data.reset_index()
# Out:
#              bowler  isWicketDelivery
# 0    A Ashish Reddy                19
# 1          A Badoni                 2
# 2        A Chandila                11
# 3       A Choudhary                 5
# 4       A Dananjaya                 0
# ..              ...               ...
# 467       YK Pathan                46
# 468       YS Chahal               172
# 469      Yash Dayal                13
# 470    Yuvraj Singh                39
# 471          Z Khan               119
#
# [472 rows x 2 columns]
